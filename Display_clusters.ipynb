# %%
from clusterizator import *

# %%
centers = ([6, 4], [-8, -3], [-5, 5])
n_cluster = len(centers)
clusters_size = [100] * n_cluster

# %%
dataset = create_dataset(centers, clusters_size)

# %%
results = clusterize(dataset, n_cluster)
#results

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(*dataset.T, marker='.', color='blue')
for c in results['clusters_centroids']:
    plt.scatter(*c, marker='x', color='red')
